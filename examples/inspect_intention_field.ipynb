# %%
from elysia_world.world import World
world = World(primordial_dna={"instinct": "connect_create_meaning"}, wave_mechanics=None)
intent = world.intentional_field
intent.shape
